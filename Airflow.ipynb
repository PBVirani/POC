# %%
# Airflow needs a home. `~/airflow` is the default, but you can put it
# somewhere else if you prefer (optional)
export AIRFLOW_HOME=~/airflow

# Install Airflow using the constraints file
AIRFLOW_VERSION=2.5.1
PYTHON_VERSION="$(python --version | cut -d " " -f 2 | cut -d "." -f 1-2)"
# For example: 3.7
CONSTRAINT_URL="https://raw.githubusercontent.com/apache/airflow/constraints-${AIRFLOW_VERSION}/constraints-${PYTHON_VERSION}.txt"
# For example: https://raw.githubusercontent.com/apache/airflow/constraints-2.5.1/constraints-3.7.txt
pip install "apache-airflow==${AIRFLOW_VERSION}" --constraint "${CONSTRAINT_URL}"

# The Standalone command will initialise the database, make a user,
# and start all components for you.
airflow standalone

# Visit localhost:8080 in the browser and use the admin account details
# shown on the terminal to login.
# Enable the example_bash_operator dag in the home page
# Out:
#   File "C:\Users\Prince Virani\AppData\Local\Temp\ipykernel_14536\1056292273.py", line 3
#     export AIRFLOW_HOME=~/airflow
#            ^
# SyntaxError: invalid syntax

# %%
pip install "apache-airflow[celery]==2.5.1" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-2.5.1/constraints-3.7.txt"
# Out:
# Collecting apache-airflow[celery]==2.5.1
#   Downloading apache_airflow-2.5.1-py3-none-any.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: pathspec~=0.9.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.9.0)
# Requirement already satisfied: packaging>=14.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (21.3)
# Collecting werkzeug>=2.0
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      -------------------------------------- 232.7/232.7 kB 7.2 MB/s eta 0:00:00
# Collecting blinker
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.2.32.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting configupdater>=3.1.1
#   Downloading ConfigUpdater-3.1.1-py2.py3-none-any.whl (34 kB)
# Collecting cryptography>=0.9.3
#   Using cached cryptography-38.0.4-cp36-abi3-win_amd64.whl (2.4 MB)
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting croniter>=0.3.17
#   Downloading croniter-1.3.8-py2.py3-none-any.whl (18 kB)
# Collecting apache-airflow-providers-common-sql
#   Downloading apache_airflow_providers_common_sql-1.3.3-py3-none-any.whl (31 kB)
# Collecting flask-login>=0.6.2
#   Downloading Flask_Login-0.6.2-py3-none-any.whl (17 kB)
# Collecting argcomplete>=1.10
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.5/79.5 kB 4.3 MB/s eta 0:00:00
# Collecting jsonschema>=3.2.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ---------------------------------------- 90.4/90.4 kB 5.0 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-4.1.1-py3-none-any.whl (21 kB)
# Collecting jinja2>=3.0.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 4.0 MB/s eta 0:00:00
# Collecting attrs>=22.1.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.0/60.0 kB 3.1 MB/s eta 0:00:00
# Collecting python-daemon>=2.2.4
#   Downloading python_daemon-2.3.2-py3-none-any.whl (34 kB)
# Collecting python-slugify>=5.0
#   Downloading python_slugify-7.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting markdown-it-py>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.5/84.5 kB 5.0 MB/s eta 0:00:00
# Collecting psutil>=4.2.0
#   Downloading psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
#      -------------------------------------- 252.5/252.5 kB 5.2 MB/s eta 0:00:00
# Collecting pygments>=2.0.1
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 5.9 MB/s eta 0:00:00
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting sqlalchemy<2.0,>=1.4
#   Downloading SQLAlchemy-1.4.46-cp39-cp39-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 5.9 MB/s eta 0:00:00
# Collecting markupsafe>=1.1.1
#   Downloading MarkupSafe-2.1.2-cp39-cp39-win_amd64.whl (16 kB)
# Collecting flask-session>=0.4.0
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting linkify-it-py>=2.0.0
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.1.post0-py3-none-any.whl (10 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-3.3.1-py3-none-any.whl (14 kB)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting flask-wtf>=0.15
#   Downloading Flask_WTF-1.1.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: pluggy>=1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.0.0)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.6.0)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      -------------------------------------- 152.0/152.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.3.2-cp39-cp39-win_amd64.whl (11 kB)
# Collecting flask-appbuilder==4.1.4
#   Downloading Flask_AppBuilder-4.1.4-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 6.0 MB/s eta 0:00:00
# Collecting alembic<2.0,>=1.6.3
#   Downloading alembic-1.9.2-py3-none-any.whl (210 kB)
#      -------------------------------------- 210.6/210.6 kB 6.5 MB/s eta 0:00:00
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Collecting tabulate>=0.7.5
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting flask-caching>=1.5.0
#   Downloading Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.9.0-cp39-cp39-win_amd64.whl (22 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.4.0)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.5/71.5 kB 3.8 MB/s eta 0:00:00
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#      ---------------------------------------- 81.2/81.2 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.8.2)
# Collecting markdown>=3.0
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.3/93.3 kB ? eta 0:00:00
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.3.0-py3-none-any.whl (19 kB)
# Collecting cattrs>=22.1.0
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Collecting connexion[flask]>=2.10.0
#   Downloading connexion-2.14.1-py2.py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.1/95.1 kB 5.3 MB/s eta 0:00:00
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-3.1.1-py3-none-any.whl (17 kB)
# Collecting flask<2.3,>=2.2
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.5/101.5 kB ? eta 0:00:00
# Collecting mdit-py-plugins>=0.3.0
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.5/50.5 kB ? eta 0:00:00
# Collecting graphviz>=0.12
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB 2.5 MB/s eta 0:00:00
# Collecting rich>=12.4.4
#   Downloading rich-13.1.0-py3-none-any.whl (238 kB)
#      -------------------------------------- 238.4/238.4 kB 4.9 MB/s eta 0:00:00
# Collecting celery<6,>=5.2.3
#   Downloading celery-5.2.7-py3-none-any.whl (405 kB)
#      -------------------------------------- 405.6/405.6 kB 6.4 MB/s eta 0:00:00
# Collecting flower>=1.0.0
#   Downloading flower-1.2.0-py2.py3-none-any.whl (410 kB)
#      -------------------------------------- 410.7/410.7 kB 5.1 MB/s eta 0:00:00
# Collecting apache-airflow-providers-celery
#   Downloading apache_airflow_providers_celery-3.1.0-py3-none-any.whl (12 kB)
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.3.0-py2.py3-none-any.whl (22 kB)
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.39.0-py3-none-any.whl (92 kB)
#      ---------------------------------------- 92.5/92.5 kB ? eta 0:00:00
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.1/49.1 kB 2.4 MB/s eta 0:00:00
# Collecting colorama<1,>=0.3.9
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0
#   Downloading Flask_JWT_Extended-4.4.4-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting click<9,>=8
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting WTForms<4
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      -------------------------------------- 136.5/136.5 kB 8.4 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB 4.6 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting click-didyoumean>=0.0.3
#   Downloading click_didyoumean-0.3.0-py3-none-any.whl (2.7 kB)
# Collecting billiard<4.0,>=3.6.4.0
#   Downloading billiard-3.6.4.0-py3-none-any.whl (89 kB)
#      ---------------------------------------- 89.5/89.5 kB 5.0 MB/s eta 0:00:00
# Collecting click-repl>=0.2.0
#   Downloading click_repl-0.2.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pytz>=2021.3 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (2022.7.1)
# Collecting kombu<6.0,>=5.2.3
#   Downloading kombu-5.2.4-py3-none-any.whl (189 kB)
#      -------------------------------------- 189.2/189.2 kB 5.8 MB/s eta 0:00:00
# Collecting vine<6.0,>=5.0.0
#   Downloading vine-5.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting click-plugins>=1.1.1
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (2.28.2)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (6.0)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (0.5.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\prince virani\anaconda3\lib\site-packages (from cryptography>=0.9.3->apache-airflow[celery]==2.5.1) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\prince virani\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow[celery]==2.5.1) (1.14.1)
# Collecting importlib-metadata>=3.6.0
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting cachelib<0.10.0,>=0.9.0
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Collecting prometheus-client>=0.8.0
#   Downloading prometheus_client-0.15.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.1/60.1 kB ? eta 0:00:00
# Collecting humanize
#   Downloading humanize-4.4.0-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.6/106.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7.0.0,>=5.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow[celery]==2.5.1) (6.1)
# Requirement already satisfied: setuptools>=3.0 in c:\users\prince virani\anaconda3\lib\site-packages (from gunicorn>=20.1.0->apache-airflow[celery]==2.5.1) (63.4.1)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp39-cp39-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\prince virani\anaconda3\lib\site-packages (from packaging>=14.0->apache-airflow[celery]==2.5.1) (3.0.9)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      -------------------------------------- 490.0/490.0 kB 6.2 MB/s eta 0:00:00
# Collecting docutils
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      -------------------------------------- 570.5/570.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\prince virani\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow[celery]==2.5.1) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\prince virani\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow[celery]==2.5.1) (1.3)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.1/51.1 kB 2.7 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.1-cp39-cp39-win_amd64.whl (190 kB)
#      -------------------------------------- 190.7/190.7 kB 5.8 MB/s eta 0:00:00
# Collecting sqlparse>=0.4.2
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB 2.2 MB/s eta 0:00:00
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ---------------------------------------- 69.6/69.6 kB ? eta 0:00:00
# Requirement already satisfied: certifi in c:\users\prince virani\anaconda3\lib\site-packages (from httpx->apache-airflow[celery]==2.5.1) (2022.12.7)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pycparser in c:\users\prince virani\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow[celery]==2.5.1) (2.21)
# Collecting prompt-toolkit
#   Downloading prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
#      -------------------------------------- 386.4/386.4 kB 6.1 MB/s eta 0:00:00
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      -------------------------------------- 283.7/283.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (3.4)
# Collecting Babel>=2.3
#   Downloading Babel-2.11.0-py3-none-any.whl (9.5 MB)
#      ---------------------------------------- 9.5/9.5 MB 5.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.6/80.6 kB ? eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting amqp<6.0.0,>=5.0.9
#   Downloading amqp-5.1.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.8/50.8 kB ? eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prince virani\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (1.26.14)
# Collecting wcwidth
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: cron-descriptor, dill, pendulum, python-nvd3, unicodecsv
#   Building wheel for cron-descriptor (setup.py): started
#   Building wheel for cron-descriptor (setup.py): finished with status 'done'
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.2.32-py3-none-any.whl size=46728 sha256=b24e2404651e64cc032b7b1c66bc7e48bde50a09c187e8157e4ee2047b14f992
#   Stored in directory: c:\users\prince virani\appdata\local\pip\cache\wheels\62\6f\ad\ac401d9d574d2c272e1726b78874173d975af721fd54655175
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78628 sha256=6ade11d36411bf277d8c1f0595c3ea1c22601b645e4ae21be02dd2d653ed465a
#   Stored in directory: c:\users\prince virani\appdata\local\pip\cache\wheels\4f\0b\ce\75d96dd714b15e51cb66db631183ea3844e0c4a6d19741a149
#   Building wheel for pendulum (pyproject.toml): started
#   Building wheel for pendulum (pyproject.toml): finished with status 'done'
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp39-cp39-win_amd64.whl size=109763 sha256=15597879b46fc3168095be95496e07f42e199df6c5ff31d7e38df7cb196441d8
#   Stored in directory: c:\users\prince virani\appdata\local\pip\cache\wheels\c9\c7\29\3cf0033406b18958d1a7b107c38be2405ef9c081b64a264fd5
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38149 sha256=fa513828f9ca34508251c81082ef1b726a7fff179ad7eb0182e2a7a9f247ffe1
#   Stored in directory: c:\users\prince virani\appdata\local\pip\cache\wheels\60\e8\21\19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10746 sha256=026942bb72a16f8c292ba42d4bff46bdff0b363b6158a6b5f1170aff3a591a37
#   Stored in directory: c:\users\prince virani\appdata\local\pip\cache\wheels\d8\c8\27\b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
# Successfully built cron-descriptor dill pendulum python-nvd3 unicodecsv
# Installing collected packages: wcwidth, unicodecsv, rfc3986, lockfile, cron-descriptor, commonmark, billiard, zipp, vine, uc-micro-py, termcolor, tenacity, tabulate, sqlparse, sniffio, setproctitle, pytzdata, python-slugify, pyrsistent, pygments, psutil, prompt-toolkit, prometheus-client, prison, mdurl, markupsafe, lazy-object-proxy, itsdangerous, humanize, h11, gunicorn, greenlet, graphviz, exceptiongroup, docutils, dnspython, dill, deprecated, configupdater, colorama, charset-normalizer, cachelib, blinker, Babel, attrs, argcomplete, apispec, apache-airflow-providers-imap, apache-airflow-providers-ftp, WTForms, werkzeug, sqlalchemy, rich, python-daemon, pendulum, marshmallow, markdown-it-py, Mako, linkify-it-py, jsonschema, jinja2, importlib-metadata, email-validator, cryptography, croniter, colorlog, click, cattrs, apache-airflow-providers-common-sql, anyio, amqp, sqlalchemy-utils, sqlalchemy-jsonfield, requests-toolbelt, python-nvd3, mdit-py-plugins, marshmallow-sqlalchemy, marshmallow-oneofschema, marshmallow-enum, markdown, kombu, httpcore, flask, clickclick, click-repl, click-plugins, click-didyoumean, apache-airflow-providers-sqlite, alembic, httpx, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-JWT-Extended, flask-caching, Flask-Babel, connexion, celery, apache-airflow-providers-http, flower, flask-appbuilder, apache-airflow, apache-airflow-providers-celery
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.8.0
#     Uninstalling zipp-3.8.0:
#       Successfully uninstalled zipp-3.8.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: python-slugify
#     Found existing installation: python-slugify 5.0.2
#     Uninstalling python-slugify-5.0.2:
#       Successfully uninstalled python-slugify-5.0.2
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.18.0
#     Uninstalling pyrsistent-0.18.0:
#       Successfully uninstalled pyrsistent-0.18.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.20
#     Uninstalling prompt-toolkit-3.0.20:
#       Successfully uninstalled prompt-toolkit-3.0.20
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.14.1
#     Uninstalling prometheus-client-0.14.1:
#       Successfully uninstalled prometheus-client-0.14.1
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: lazy-object-proxy
#     Found existing installation: lazy-object-proxy 1.6.0
#     Uninstalling lazy-object-proxy-1.6.0:
#       Successfully uninstalled lazy-object-proxy-1.6.0
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 2.0.1
#     Uninstalling itsdangerous-2.0.1:
#       Successfully uninstalled itsdangerous-2.0.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.1
#     Uninstalling greenlet-1.1.1:
#       Successfully uninstalled greenlet-1.1.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.9.1
#     Uninstalling Babel-2.9.1:
#       Successfully uninstalled Babel-2.9.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.16.0
#     Uninstalling jsonschema-4.16.0:
#       Successfully uninstalled jsonschema-4.16.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 36.0.2
#     Uninstalling cryptography-36.0.2:
#       Successfully uninstalled cryptography-36.0.2
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.3.4
#     Uninstalling Markdown-3.3.4:
#       Successfully uninstalled Markdown-3.3.4
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.2
#     Uninstalling Flask-1.1.2:
#       Successfully uninstalled Flask-1.1.2
# Successfully installed Babel-2.11.0 Flask-Babel-2.0.0 Flask-JWT-Extended-4.4.4 Flask-SQLAlchemy-2.5.1 Mako-1.2.4 WTForms-3.0.1 alembic-1.9.2 amqp-5.1.1 anyio-3.6.2 apache-airflow-2.5.1 apache-airflow-providers-celery-3.1.0 apache-airflow-providers-common-sql-1.3.3 apache-airflow-providers-ftp-3.3.0 apache-airflow-providers-http-4.1.1 apache-airflow-providers-imap-3.1.1 apache-airflow-providers-sqlite-3.3.1 apispec-3.3.2 argcomplete-2.0.0 attrs-22.2.0 billiard-3.6.4.0 blinker-1.5 cachelib-0.9.0 cattrs-22.2.0 celery-5.2.7 charset-normalizer-2.1.1 click-8.1.3 click-didyoumean-0.3.0 click-plugins-1.1.1 click-repl-0.2.0 clickclick-20.10.2 colorama-0.4.6 colorlog-4.8.0 commonmark-0.9.1 configupdater-3.1.1 connexion-2.14.1 cron-descriptor-1.2.32 croniter-1.3.8 cryptography-38.0.4 deprecated-1.2.13 dill-0.3.1.1 dnspython-2.3.0 docutils-0.19 email-validator-1.3.0 exceptiongroup-1.1.0 flask-2.2.2 flask-appbuilder-4.1.4 flask-caching-2.0.2 flask-login-0.6.2 flask-session-0.4.0 flask-wtf-1.1.1 flower-1.2.0 graphviz-0.20.1 greenlet-2.0.1 gunicorn-20.1.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 humanize-4.4.0 importlib-metadata-4.13.0 itsdangerous-2.1.2 jinja2-3.1.2 jsonschema-4.17.3 kombu-5.2.4 lazy-object-proxy-1.9.0 linkify-it-py-2.0.0 lockfile-0.12.2 markdown-3.4.1 markdown-it-py-2.1.0 markupsafe-2.1.2 marshmallow-3.19.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.3.3 mdurl-0.1.2 pendulum-2.1.2 prison-0.2.1 prometheus-client-0.15.0 prompt-toolkit-3.0.36 psutil-5.9.4 pygments-2.14.0 pyrsistent-0.19.3 python-daemon-2.3.2 python-nvd3-0.15.0 python-slugify-7.0.0 pytzdata-2020.1 requests-toolbelt-0.10.1 rfc3986-1.5.0 rich-13.1.0 setproctitle-1.3.2 sniffio-1.3.0 sqlalchemy-1.4.46 sqlalchemy-jsonfield-1.0.1.post0 sqlalchemy-utils-0.39.0 sqlparse-0.4.3 tabulate-0.9.0 tenacity-8.1.0 termcolor-2.2.0 uc-micro-py-1.0.1 unicodecsv-0.14.1 vine-5.0.0 wcwidth-0.2.6 werkzeug-2.2.2 zipp-3.11.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# sphinx 5.0.2 requires docutils<0.19,>=0.14, but you have docutils 0.19 which is incompatible.
# snowflake-connector-python 2.7.9 requires charset-normalizer~=2.0.0, but you have charset-normalizer 2.1.1 which is incompatible.
# snowflake-connector-python 2.7.9 requires cryptography<37.0.0,>=3.1.0, but you have cryptography 38.0.4 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.28.2 which is incompatible.

# %%
pip install "apache-airflow[celery]==2.5.1" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-2.5.1/constraints-3.7.txt"
# Out:
# Requirement already satisfied: apache-airflow[celery]==2.5.1 in c:\users\prince virani\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.1.2)
# Requirement already satisfied: graphviz>=0.12 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.20.1)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.3.1)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.15.0)
# Requirement already satisfied: httpx in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.23.3)
# Requirement already satisfied: packaging>=14.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (21.3)
# Requirement already satisfied: dill>=0.2.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.3.1.1)
# Requirement already satisfied: lazy-object-proxy in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.1.0)
# Requirement already satisfied: blinker in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.5)
# Requirement already satisfied: connexion[flask]>=2.10.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.14.1)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.1.2)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.0.0)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (22.2.0)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.8.2)
# Requirement already satisfied: croniter>=0.3.17 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.3.8)
# Requirement already satisfied: flask-wtf>=0.15 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.1.1)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.3.3)
# Requirement already satisfied: pathspec~=0.9.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.4.0)
# Requirement already satisfied: pendulum>=2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.1.2)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.1.1)
# Requirement already satisfied: alembic<2.0,>=1.6.3 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.9.2)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.1.2)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.6.0)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.8.0)
# Requirement already satisfied: markdown>=3.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.4.1)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.3.0)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.2.32)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.17.3)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.2.13)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.12.2)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.0.1.post0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.2.0)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.4.46)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.1.1)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.6.2)
# Requirement already satisfied: cattrs>=22.1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (22.2.0)
# Requirement already satisfied: flask<2.3,>=2.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.2.2)
# Requirement already satisfied: rich>=12.4.4 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (13.1.0)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (5.9.4)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.9.0)
# Requirement already satisfied: werkzeug>=2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.2.2)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.1.1)
# Requirement already satisfied: python-daemon>=2.2.4 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.3.2)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (20.1.0)
# Requirement already satisfied: flask-caching>=1.5.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.0.2)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.0.0)
# Requirement already satisfied: pluggy>=1.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.0.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (2.14.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.14.1)
# Requirement already satisfied: flask-session>=0.4.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.4.0)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.0.1)
# Requirement already satisfied: cryptography>=0.9.3 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (38.0.4)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (7.0.0)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (0.3.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (8.1.0)
# Requirement already satisfied: flask-appbuilder==4.1.4 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (4.1.4)
# Requirement already satisfied: setproctitle>=1.1.8 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.3.2)
# Requirement already satisfied: celery<6,>=5.2.3 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (5.2.7)
# Requirement already satisfied: flower>=1.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (1.2.0)
# Requirement already satisfied: apache-airflow-providers-celery in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow[celery]==2.5.1) (3.1.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (2.5.1)
# Requirement already satisfied: click<9,>=8 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (8.1.3)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (0.39.0)
# Requirement already satisfied: marshmallow<4,>=3 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (3.19.0)
# Requirement already satisfied: email-validator<2,>=1.0.5 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (1.3.0)
# Requirement already satisfied: apispec[yaml]<4,>=3.3 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (3.3.2)
# Requirement already satisfied: marshmallow-enum<2,>=1.5.1 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (1.5.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (0.4.6)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (0.26.1)
# Requirement already satisfied: WTForms<4 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (3.0.1)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (0.2.1)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (2.0.0)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (4.4.4)
# Requirement already satisfied: Mako in c:\users\prince virani\anaconda3\lib\site-packages (from alembic<2.0,>=1.6.3->apache-airflow[celery]==2.5.1) (1.2.4)
# Requirement already satisfied: exceptiongroup in c:\users\prince virani\anaconda3\lib\site-packages (from cattrs>=22.1.0->apache-airflow[celery]==2.5.1) (1.1.0)
# Requirement already satisfied: kombu<6.0,>=5.2.3 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (5.2.4)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (1.1.1)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (0.2.0)
# Requirement already satisfied: click-didyoumean>=0.0.3 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (0.3.0)
# Requirement already satisfied: vine<6.0,>=5.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (5.0.0)
# Requirement already satisfied: pytz>=2021.3 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (2022.7.1)
# Requirement already satisfied: billiard<4.0,>=3.6.4.0 in c:\users\prince virani\anaconda3\lib\site-packages (from celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (3.6.4.0)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (6.0)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (0.5.1)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (20.10.2)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\prince virani\anaconda3\lib\site-packages (from connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (2.28.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\prince virani\anaconda3\lib\site-packages (from cryptography>=0.9.3->apache-airflow[celery]==2.5.1) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\prince virani\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow[celery]==2.5.1) (1.14.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flask<2.3,>=2.2->apache-airflow[celery]==2.5.1) (4.13.0)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flask-caching>=1.5.0->apache-airflow[celery]==2.5.1) (0.9.0)
# Requirement already satisfied: humanize in c:\users\prince virani\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow[celery]==2.5.1) (4.4.0)
# Requirement already satisfied: prometheus-client>=0.8.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow[celery]==2.5.1) (0.15.0)
# Requirement already satisfied: tornado<7.0.0,>=5.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow[celery]==2.5.1) (6.1)
# Requirement already satisfied: setuptools>=3.0 in c:\users\prince virani\anaconda3\lib\site-packages (from gunicorn>=20.1.0->apache-airflow[celery]==2.5.1) (63.4.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\prince virani\anaconda3\lib\site-packages (from jsonschema>=3.2.0->apache-airflow[celery]==2.5.1) (0.19.3)
# Requirement already satisfied: uc-micro-py in c:\users\prince virani\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow[celery]==2.5.1) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prince virani\anaconda3\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow[celery]==2.5.1) (0.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\prince virani\anaconda3\lib\site-packages (from packaging>=14.0->apache-airflow[celery]==2.5.1) (3.0.9)
# Requirement already satisfied: pytzdata>=2020.1 in c:\users\prince virani\anaconda3\lib\site-packages (from pendulum>=2.0->apache-airflow[celery]==2.5.1) (2020.1)
# Requirement already satisfied: docutils in c:\users\prince virani\anaconda3\lib\site-packages (from python-daemon>=2.2.4->apache-airflow[celery]==2.5.1) (0.19)
# Requirement already satisfied: six>=1.5 in c:\users\prince virani\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow[celery]==2.5.1) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\prince virani\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow[celery]==2.5.1) (1.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\prince virani\anaconda3\lib\site-packages (from rich>=12.4.4->apache-airflow[celery]==2.5.1) (0.9.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\prince virani\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4->apache-airflow[celery]==2.5.1) (2.0.1)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow[celery]==2.5.1) (0.4.3)
# Requirement already satisfied: requests-toolbelt in c:\users\prince virani\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow[celery]==2.5.1) (0.10.1)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\prince virani\anaconda3\lib\site-packages (from httpx->apache-airflow[celery]==2.5.1) (1.5.0)
# Requirement already satisfied: certifi in c:\users\prince virani\anaconda3\lib\site-packages (from httpx->apache-airflow[celery]==2.5.1) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\prince virani\anaconda3\lib\site-packages (from httpx->apache-airflow[celery]==2.5.1) (0.16.3)
# Requirement already satisfied: sniffio in c:\users\prince virani\anaconda3\lib\site-packages (from httpx->apache-airflow[celery]==2.5.1) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\prince virani\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow[celery]==2.5.1) (2.21)
# Requirement already satisfied: prompt-toolkit in c:\users\prince virani\anaconda3\lib\site-packages (from click-repl>=0.2.0->celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (3.0.36)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\prince virani\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (2.3.0)
# Requirement already satisfied: idna>=2.0.0 in c:\users\prince virani\anaconda3\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (3.4)
# Requirement already satisfied: Babel>=2.3 in c:\users\prince virani\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow[celery]==2.5.1) (2.11.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prince virani\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow[celery]==2.5.1) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\prince virani\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow[celery]==2.5.1) (3.6.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\prince virani\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow[celery]==2.5.1) (3.11.0)
# Requirement already satisfied: amqp<6.0.0,>=5.0.9 in c:\users\prince virani\anaconda3\lib\site-packages (from kombu<6.0,>=5.2.3->celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prince virani\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prince virani\anaconda3\lib\site-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow[celery]==2.5.1) (1.26.14)
# Requirement already satisfied: wcwidth in c:\users\prince virani\anaconda3\lib\site-packages (from prompt-toolkit->click-repl>=0.2.0->celery<6,>=5.2.3->apache-airflow[celery]==2.5.1) (0.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
